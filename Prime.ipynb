# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the prime data from the CSV file
data = pd.read_csv('/content/prime.csv')
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Drop the `cast` column
data = data.drop(columns=['cast'])

# %%
# Remove null values in the `director` and `country` columns
data = data.dropna(subset=['director', 'country'])

# %%
# Get the unique directors
unique_directors = data['director'].unique()

# %%
# Count the number of movies by director
director_counts = data['director'].value_counts()

# %%
# Describe the numeric values
data.describe()
# Out:
#        release_year
# count   5751.000000
# mean    2012.920536
# std        9.772461
# min     1942.000000
# 25%     2012.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2021.000000

# %%
# Create a heatmap of the missing values
sns.heatmap(data.isnull())
plt.show()

# %%
# Get the number of movies by release year
release_year_counts = data['release_year'].value_counts()

# %%
# Get the number of movies by type
type_counts = data['type'].value_counts()

# %%
# Plot a bar chart of the number of movies by type
type_counts.plot(kind='bar')
plt.show()

# %%
# returns the top 5 directors by number of movies in the prime.csv DataFrame
data['director'].value_counts().head(5)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Name: director, dtype: int64

# %%
# Plot a bar chart of the top 5 directors by number of movies
top_directors.plot(kind='bar')
plt.show()

# %%
# Get the movies directed by Mark Knight
mark_knight_movies = data[(data['type']== 'movie')&(data['director']== 'Mark Knight')]

# %%
# Show the first 5 movies directed by Mark Knight
mark_knight_movies.head()

# %%
# Create a stripplot of the rating vs. release year
sns.stripplot(x='release_year', y='rating', data=data)
plt.show()
